# %% [markdown]
# <a href="https://colab.research.google.com/github/GAETANNGALEU23/Irisrepository/blob/main/TpMpg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder

# %%
B = pd.read_csv('auto-mpg.csv', delimiter=",")

# %%
B
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin  car name
# 0            70       1        49
# 1            70       1        36
# 2            70       1       231
# ...

# %%
B.columns
# Out:
# Index(['mpg', 'cylinders', 'displacement', 'horsepower', 'weight',
#        'acceleration', 'model year', 'origin', 'car name'],
#       dtype='object')

# %%
B.shape
# Out:
# (398, 9)

# %%
B.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    object
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model year    398 non-null    int64
#  7   origin        398 non-null    int64
#  8   car name      398 non-null    int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 28.1+ KB

# %%
print("Le nombre d'occurence de chaque classes:")
counts = B['mpg'].value_counts()
print(counts)
# Out:
# Le nombre d'occurence de chaque classes:
# mpg
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: count, Length: 129, dtype: int64

# %%
print('Le type de variables:')
B.dtypes
# Out:
# Le type de variables:
# mpg             float64
# cylinders         int64
# displacement    float64
# horsepower       object
# weight            int64
# acceleration    float64
# model year        int64
# origin            int64
# car name          int64
# dtype: object

# %%
B['mpg'].value_counts()
# Out:
# mpg
# 13.0    20
# 14.0    19
# 18.0    17
# 15.0    16
# 26.0    14
#         ..
# 31.9     1
# 16.9     1
# 18.2     1
# 22.3     1
# 44.0     1
# Name: count, Length: 129, dtype: int64

# %%
B.groupby(['mpg']).sum().plot(kind="bar")
# Out:
# <Axes: xlabel='mpg'>

# %%
B.groupby(['mpg']).sum()
# Out:
#       cylinders  displacement  \
# mpg
# 9.0           8         304.0
# 10.0         16         667.0
# 11.0         32        1497.0
# 12.0         48        2367.0
# 13.0        160        7060.0
# ...         ...           ...
# 43.4          4          90.0
# 44.0          4          97.0
# 44.3          4          90.0
# 44.6          4          91.0
# 46.6          4          86.0
#
#                                              horsepower  weight  acceleration  \
# mpg
# 9.0                                                 193    4732          18.5
# 10.0                                             215200    8991          29.0
# 11.0                                       210208150180   17676          49.5
# 12.0                                 180160198225167180   28719          72.5
# 13.0  1701751651551901301401751451501582151751701501...   85089         258.7
# ...                                                 ...     ...           ...
# ...

# %%
sn.countplot(B, x="mpg", hue="mpg")
# Out:
# <Axes: xlabel='mpg', ylabel='count'>

# %%
sn.countplot(B, x="cylinders", hue="mpg")
# Out:
# <Axes: xlabel='cylinders', ylabel='count'>

# %%
sn.countplot(B, x="acceleration", hue="mpg")
# Out:
# <Axes: xlabel='acceleration', ylabel='count'>

# %%
plt.figure(figsize=(8,8))

# Ajouter le sous-graphe à la position de grille spécifiée
# position de la grille
plt.subplot(2,2,1)
sn.scatterplot(data=B, x="cylinders", y="horsepower", hue="mpg", palette=['gold', 'orchid', 'green', "#77BFE2"])

plt.subplot(2,2,2)
sn.scatterplot(data=B, x="displacement", y="weight", hue="mpg", palette=['gold', 'orchid', 'green', "#77BFE2"])

plt.subplot(2,2,3)
sn.scatterplot(data=B, x="car name", y="model year", hue="mpg", palette=['gold', 'orchid', 'green', "#77BFE2"])

plt.subplot(2,2,4)
sn.scatterplot(data=B, x="origin", y="acceleration", hue="mpg", palette=['gold', 'orchid', 'green', "#77BFE2"])

plt.show()
# Out:
# <ipython-input-78-cddd9df63665>:6: UserWarning:
# The palette list has fewer values (4) than needed (129) and will cycle, which may produce an uninterpretable plot.
#   sn.scatterplot(data=B, x="cylinders", y="horsepower", hue="mpg", palette=['gold', 'orchid', 'green', "#77BFE2"])
# <ipython-input-78-cddd9df63665>:9: UserWarning:
# The palette list has fewer values (4) than needed (129) and will cycle, which may produce an uninterpretable plot.
#   sn.scatterplot(data=B, x="displacement", y="weight", hue="mpg", palette=['gold', 'orchid', 'green', "#77BFE2"])
# <ipython-input-78-cddd9df63665>:12: UserWarning:
# The palette list has fewer values (4) than needed (129) and will cycle, which may produce an uninterpretable plot.
#   sn.scatterplot(data=B, x="car name", y="model year", hue="mpg", palette=['gold', 'orchid', 'green', "#77BFE2"])
# <ipython-input-78-cddd9df63665>:15: UserWarning:
# ...

# %%
sn.pairplot(B, hue="mpg", palette=['gold', 'orchid', 'green'])
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning:
# The palette list has fewer values (3) than needed (129) and will cycle, which may produce an uninterpretable plot.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning:
# The palette list has fewer values (3) than needed (129) and will cycle, which may produce an uninterpretable plot.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning:
# The palette list has fewer values (3) than needed (129) and will cycle, which may produce an uninterpretable plot.
#   func(x=vector, **plot_kwargs)
# /usr/local/lib/python3.10/dist-packages/seaborn/axisgrid.py:1513: UserWarning:
# The palette list has fewer values (3) than needed (129) and will cycle, which may produce an uninterpretable plot.
#   func(x=vector, **plot_kwargs)
# ...

# %%
sn.boxplot(B, x="mpg", y="acceleration", palette=['gold', 'orchid', 'green', "#77BFE2"])

# %%
plt.figure(figsize=(8,8))

# Ajouter le sous-graphe à la position de grille spécifiée
# position de la grille
plt.subplot(221)
sn.boxplot(x="mpg", y="cylinders", data=B, hue="mpg", palette=['gold', 'orchid', 'green'])

plt.subplot(222)
sn.boxplot(x="mpg", y="displacement", data=B, hue="mpg", palette=['gold', 'orchid', 'green'])

plt.subplot(223)
sn.boxplot(x="mpg", y="acceleration", data=B, hue="mpg", palette=['gold', 'orchid', 'green'])

plt.subplot(224)
sn.boxplot(x="mpg", y="weight", data=B, hue="mpg", palette=['gold', 'orchid', 'green'])

# %%
sn.heatmap(B.select_dtypes(include=['number']).corr(method='pearson'), annot = True);

# %%
from sklearn.preprocessing import LabelEncoder
encoder = LabelEncoder()
B['car name'] = encoder.fit_transform(B['car name'])
B
# Out:
#       mpg  cylinders  displacement horsepower  weight  acceleration  \
# 0    18.0          8         307.0        130    3504          12.0
# 1    15.0          8         350.0        165    3693          11.5
# 2    18.0          8         318.0        150    3436          11.0
# 3    16.0          8         304.0        150    3433          12.0
# 4    17.0          8         302.0        140    3449          10.5
# ..    ...        ...           ...        ...     ...           ...
# 393  27.0          4         140.0         86    2790          15.6
# 394  44.0          4          97.0         52    2130          24.6
# 395  32.0          4         135.0         84    2295          11.6
# 396  28.0          4         120.0         79    2625          18.6
# 397  31.0          4         119.0         82    2720          19.4
#
#      model year  origin  car name
# 0            70       1        49
# 1            70       1        36
# 2            70       1       231
# ...

# %%
X = B.drop('mpg', axis=1)
y = B['mpg']

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
 encoder = LabelEncoder()
B['car name'] = encoder.fit_transform(B['car name'])
B
print("X_train :\n", X_train)
print("X_test :\n", X_test)
print("y_train :\n", y_train)
print("y_test :\n", y_test)
# Out:
# X_train :
#       cylinders  displacement horsepower  weight  acceleration  model year  \
# 157          8         350.0        145    4440          14.0          75
# 109          4         140.0         72    2401          19.5          73
# 17           6         200.0         85    2587          16.0          70
# 253          6         200.0         95    3155          18.2          78
# 24           6         199.0         90    2648          15.0          70
# ..         ...           ...        ...     ...           ...         ...
# 71           3          70.0         97    2330          13.5          72
# 106          8         350.0        180    4499          12.5          73
# 270          4         134.0         95    2515          14.8          78
# 348          4          89.0         62    2050          17.3          81
# 102          4          97.0         46    1950          21.0          73
#
#      origin                   car name
# ...

# %% [markdown]
# MODELE KNN (K NEAREST NEIGBORS)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=3)
